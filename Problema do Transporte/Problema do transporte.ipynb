# %%
from pyomo.environ import *

# %%
model = AbstractModel(name = "Transporte_AbstractModel")
model.N = Set() # Conjunto localidades de oferta
model.M = Set() # Conjunto localidades de demanda
model.CT = Param() # Custo de transporte / KM * M^3
model.D = Param(model.N, model.M) # Matriz de distâncias
model.OFER = Param(model.N) # Vetor de ofertas 'o'
model.DEM = Param(model.M) # Vetor de demandas 'r'

# Variavel de fluxo
model.f = Var(model.N, model.M, within = NonNegativeReals)

# Função objetivo: aquela que queremos minimizar!
def fobjetivo(model):
    return sum(model.D[n,m] * model.CT * model.f[n,m] for n in model.N for m in model.M)
    
model.obj = Objective(rule=fobjetivo)

# Restrição sobre a demanda
def rest_DEMANDA(model, m):
    return sum(model.f[n,m] for n in model.N) >= model.DEM[m]

model.DEMANDA = Constraint(model.M, rule = rest_DEMANDA)

# Restrição sobre a oferta
def rest_OFERTA(model, n):
    return sum(model.f[n,m] for m in model.M) <= model.OFER[n]

model.OFERTA = Constraint(model.N, rule = rest_OFERTA)

# %%
instance = model.create_instance('dados.dat')
solver = SolverFactory('glpk', executable='/home/doc/anaconda3/bin/glpsol')
solver.solve(instance)
instance.display()
instance.f.pprint()
model.pprint()
# Out:
# Model Transporte_AbstractModel
#
#   Variables:
#     f : Size=28, Index=f_index
#         Key       : Lower : Value : Upper : Fixed : Stale : Domain
#         (1, 'D1') :     0 :   0.0 :  None : False : False : NonNegativeReals
#         (1, 'D2') :     0 : 340.0 :  None : False : False : NonNegativeReals
#         (1, 'D3') :     0 :   0.0 :  None : False : False : NonNegativeReals
#         (1, 'D4') :     0 :   0.0 :  None : False : False : NonNegativeReals
#         (1, 'D5') :     0 :  90.0 :  None : False : False : NonNegativeReals
#         (1, 'D6') :     0 :  85.0 :  None : False : False : NonNegativeReals
#         (1, 'D7') :     0 : 145.0 :  None : False : False : NonNegativeReals
#         (2, 'D1') :     0 :  81.0 :  None : False : False : NonNegativeReals
#         (2, 'D2') :     0 :  54.0 :  None : False : False : NonNegativeReals
#         (2, 'D3') :     0 : 166.0 :  None : False : False : NonNegativeReals
#         (2, 'D4') :     0 :   0.0 :  None : False : False : NonNegativeReals
#         (2, 'D5') :     0 :   0.0 :  None : False : False : NonNegativeReals
#         (2, 'D6') :     0 :   0.0 :  None : False : False : NonNegativeReals
#         (2, 'D7') :     0 :   0.0 :  None : False : False : NonNegativeReals
#         (3, 'D1') :     0 : 166.0 :  None : False : False : NonNegativeReals
#         (3, 'D2') :     0 :   0.0 :  None : False : False : NonNegativeReals
#         (3, 'D3') :     0 :   0.0 :  None : False : False : NonNegativeReals
#         (3, 'D4') :     0 : 105.0 :  None : False : False : NonNegativeReals
#         (3, 'D5') :     0 :   0.0 :  None : False : False : NonNegativeReals
#         (3, 'D6') :     0 :   0.0 :  None : False : False : NonNegativeReals
#         (3, 'D7') :     0 :   0.0 :  None : False : False : NonNegativeReals
#         (4, 'D1') :     0 :   0.0 :  None : False : False : NonNegativeReals
#         (4, 'D2') :     0 :   0.0 :  None : False : False : NonNegativeReals
#         (4, 'D3') :     0 :  99.0 :  None : False : False : NonNegativeReals
#         (4, 'D4') :     0 :   0.0 :  None : False : False : NonNegativeReals
#         (4, 'D5') :     0 :   0.0 :  None : False : False : NonNegativeReals
#         (4, 'D6') :     0 :   0.0 :  None : False : False : NonNegativeReals
#         (4, 'D7') :     0 :   0.0 :  None : False : False : NonNegativeReals
#
#   Objectives:
#     obj : Size=1, Index=None, Active=True
#         Key  : Active : Value
#         None :   True : 3518.3999999999996
#
#   Constraints:
#     DEMANDA : Size=7
#         Key : Lower : Body  : Upper
#          D1 : 247.0 : 247.0 :  None
#          D2 : 394.0 : 394.0 :  None
#          D3 : 265.0 : 265.0 :  None
#          D4 : 105.0 : 105.0 :  None
#          D5 :  90.0 :  90.0 :  None
#          D6 :  85.0 :  85.0 :  None
#          D7 : 145.0 : 145.0 :  None
#     OFERTA : Size=4
#         Key : Lower : Body  : Upper
#           1 :  None : 660.0 : 660.0
#           2 :  None : 301.0 : 301.0
#           3 :  None : 271.0 : 271.0
#           4 :  None :  99.0 :  99.0
# f : Size=28, Index=f_index
#     Key       : Lower : Value : Upper : Fixed : Stale : Domain
#     (1, 'D1') :     0 :   0.0 :  None : False : False : NonNegativeReals
#     (1, 'D2') :     0 : 340.0 :  None : False : False : NonNegativeReals
#     (1, 'D3') :     0 :   0.0 :  None : False : False : NonNegativeReals
#     (1, 'D4') :     0 :   0.0 :  None : False : False : NonNegativeReals
#     (1, 'D5') :     0 :  90.0 :  None : False : False : NonNegativeReals
#     (1, 'D6') :     0 :  85.0 :  None : False : False : NonNegativeReals
#     (1, 'D7') :     0 : 145.0 :  None : False : False : NonNegativeReals
#     (2, 'D1') :     0 :  81.0 :  None : False : False : NonNegativeReals
#     (2, 'D2') :     0 :  54.0 :  None : False : False : NonNegativeReals
#     (2, 'D3') :     0 : 166.0 :  None : False : False : NonNegativeReals
#     (2, 'D4') :     0 :   0.0 :  None : False : False : NonNegativeReals
#     (2, 'D5') :     0 :   0.0 :  None : False : False : NonNegativeReals
#     (2, 'D6') :     0 :   0.0 :  None : False : False : NonNegativeReals
#     (2, 'D7') :     0 :   0.0 :  None : False : False : NonNegativeReals
#     (3, 'D1') :     0 : 166.0 :  None : False : False : NonNegativeReals
#     (3, 'D2') :     0 :   0.0 :  None : False : False : NonNegativeReals
#     (3, 'D3') :     0 :   0.0 :  None : False : False : NonNegativeReals
#     (3, 'D4') :     0 : 105.0 :  None : False : False : NonNegativeReals
#     (3, 'D5') :     0 :   0.0 :  None : False : False : NonNegativeReals
#     (3, 'D6') :     0 :   0.0 :  None : False : False : NonNegativeReals
#     (3, 'D7') :     0 :   0.0 :  None : False : False : NonNegativeReals
#     (4, 'D1') :     0 :   0.0 :  None : False : False : NonNegativeReals
#     (4, 'D2') :     0 :   0.0 :  None : False : False : NonNegativeReals
#     (4, 'D3') :     0 :  99.0 :  None : False : False : NonNegativeReals
#     (4, 'D4') :     0 :   0.0 :  None : False : False : NonNegativeReals
#     (4, 'D5') :     0 :   0.0 :  None : False : False : NonNegativeReals
#     (4, 'D6') :     0 :   0.0 :  None : False : False : NonNegativeReals
#     (4, 'D7') :     0 :   0.0 :  None : False : False : NonNegativeReals
# 4 Set Declarations
#     D_index : Size=0, Index=None, Ordered=True
#         Not constructed
#     M : Size=0, Index=None, Ordered=Insertion
#         Not constructed
#     N : Size=0, Index=None, Ordered=Insertion
#         Not constructed
#     f_index : Size=0, Index=None, Ordered=True
#         Not constructed
#
# 4 Param Declarations
#     CT : Size=0, Index=None, Domain=Any, Default=None, Mutable=False
#         Not constructed
#     D : Size=0, Index=D_index, Domain=Any, Default=None, Mutable=False
#         Not constructed
#     DEM : Size=0, Index=M, Domain=Any, Default=None, Mutable=False
#         Not constructed
#     OFER : Size=0, Index=N, Domain=Any, Default=None, Mutable=False
#         Not constructed
#
# 1 Var Declarations
#     f : Size=0, Index=f_index
#         Not constructed
#
# 1 Objective Declarations
#     obj : Size=0, Index=None, Active=True
#         Not constructed
#
# 2 Constraint Declarations
#     DEMANDA : Size=0, Index=M, Active=True
#         Not constructed
#     OFERTA : Size=0, Index=N, Active=True
#         Not constructed
#
# 12 Declarations: N M CT D_index D OFER DEM f_index f obj DEMANDA OFERTA
